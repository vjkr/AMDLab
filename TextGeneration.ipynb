# %% [markdown]
# <a href="https://colab.research.google.com/github/vjkr/AMDLab/blob/main/TextGeneration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# Sample text corpus
text = """What is deep learning? Deep learning is a subset of machine learning that uses multilayered neural networks, called deep neural networks, to simulate the complex decision-making power of the human brain. Some form of deep learning powers most of the artificial intelligence (AI) applications in our lives today.
The chief difference between deep learning and machine learning is the structure of the underlying neural network architecture. “Nondeep,” traditional machine learning models use simple neural networks with one or two computational layers. Deep learning models use three or more layers—but typically hundreds or thousands of layers—to train the models.
While supervised learning models require structured, labeled input data to make accurate outputs, deep learning models can use unsupervised learning. With unsupervised learning, deep learning models can extract the characteristics, features and relationships they need to make accurate outputs from raw, unstructured data. Additionally, these models can even evaluate and refine their outputs for increased precision.
Deep learning is an aspect of data science that drives many applications and services that improve automation, performing analytical and physical tasks without human intervention. This enables many everyday products and services—such as digital assistants, voice-enabled TV remotes, credit card fraud detection, self-driving cars and generative AI."""
chars = sorted(set(text))  # Unique characters
char_to_index = {c: i for i, c in enumerate(chars)}
index_to_char = {i: c for i, c in enumerate(chars)}

# Prepare data
sequence_length = 10
sequences = [text[i: i + sequence_length] for i in range(len(text) - sequence_length)]

X = np.array([[char_to_index[c] for c in seq] for seq in sequences[:-1]])
y = np.array([char_to_index[seq[-1]] for seq in sequences[1:]])  # Take only the last character

# %%
# Define simple RNN model
model = tf.keras.models.Sequential([
    tf.keras.layers.Embedding(len(chars), 8, input_length=sequence_length),
    tf.keras.layers.SimpleRNN(32, return_sequences=False),  # No need for return_sequences=True
    tf.keras.layers.Dense(len(chars), activation="softmax")
])

# Compile and train
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.fit(X, y, epochs=100, batch_size=8, verbose=1)  # Quick training

# Generate text
def generate_text(seed, length=50):
    for _ in range(length):
        seed_seq = np.array([[char_to_index[c] for c in seed[-sequence_length:]]])
        next_char = model.predict(seed_seq, verbose=0).argmax()
        seed += index_to_char[next_char]  # Append predicted character

    return seed  # Return after the loop finishes

# Generate new text starting with "Learning is"
print(generate_text("Learning is"))
# Out:
# Epoch 1/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.0790 - loss: 3.4606
# Epoch 2/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1152 - loss: 3.0109
# Epoch 3/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1426 - loss: 2.9949
# Epoch 4/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1495 - loss: 2.9247
# Epoch 5/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2188 - loss: 2.8370
# Epoch 6/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2335 - loss: 2.7513
# Epoch 7/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2723 - loss: 2.6379
# Epoch 8/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3006 - loss: 2.5417
# Epoch 9/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2960 - loss: 2.5080
# Epoch 10/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3086 - loss: 2.4514
# Epoch 11/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3294 - loss: 2.4191
# Epoch 12/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3631 - loss: 2.3093
# Epoch 13/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3380 - loss: 2.3072
# Epoch 14/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4069 - loss: 2.1281
# Epoch 15/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3966 - loss: 2.1359
# Epoch 16/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3919 - loss: 2.1726
# Epoch 17/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4233 - loss: 2.0456
# Epoch 18/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3948 - loss: 2.1172
# Epoch 19/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4435 - loss: 2.0046
# Epoch 20/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4406 - loss: 2.0151
# Epoch 21/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4498 - loss: 1.9732
# Epoch 22/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4542 - loss: 1.9180
# Epoch 23/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4751 - loss: 1.8475
# Epoch 24/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4754 - loss: 1.8316
# Epoch 25/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4920 - loss: 1.7787
# Epoch 26/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4955 - loss: 1.7355
# Epoch 27/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5128 - loss: 1.7365
# Epoch 28/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5177 - loss: 1.7013
# Epoch 29/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5183 - loss: 1.6840
# Epoch 30/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5314 - loss: 1.6412
# Epoch 31/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5680 - loss: 1.5751
# Epoch 32/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5455 - loss: 1.5866
# Epoch 33/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5726 - loss: 1.5134
# Epoch 34/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5588 - loss: 1.5268
# Epoch 35/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5364 - loss: 1.5265
# Epoch 36/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5795 - loss: 1.5003
# Epoch 37/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5679 - loss: 1.4884
# Epoch 38/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5919 - loss: 1.4022
# Epoch 39/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5685 - loss: 1.4596
# Epoch 40/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5938 - loss: 1.3866
# Epoch 41/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6068 - loss: 1.3676
# Epoch 42/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5979 - loss: 1.3714
# Epoch 43/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6053 - loss: 1.3514
# Epoch 44/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6236 - loss: 1.2922
# Epoch 45/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6278 - loss: 1.2653
# Epoch 46/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6326 - loss: 1.2694
# Epoch 47/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6600 - loss: 1.2116
# Epoch 48/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6294 - loss: 1.2023
# Epoch 49/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6466 - loss: 1.1589
# Epoch 50/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6401 - loss: 1.1833
# Epoch 51/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6694 - loss: 1.1435
# Epoch 52/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6833 - loss: 1.0853
# Epoch 53/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6813 - loss: 1.1158
# Epoch 54/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6771 - loss: 1.1071
# Epoch 55/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6716 - loss: 1.1521
# Epoch 56/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6780 - loss: 1.1106
# Epoch 57/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6844 - loss: 1.1001
# Epoch 58/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6712 - loss: 1.0584
# Epoch 59/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6935 - loss: 1.0759
# Epoch 60/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7052 - loss: 1.0061
# Epoch 61/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7040 - loss: 1.0012
# Epoch 62/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6986 - loss: 0.9946
# Epoch 63/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7175 - loss: 0.9963
# Epoch 64/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7143 - loss: 0.9405
# Epoch 65/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7200 - loss: 0.9446
# Epoch 66/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7344 - loss: 0.9243
# Epoch 67/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7284 - loss: 0.9303
# Epoch 68/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7524 - loss: 0.9041
# Epoch 69/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7357 - loss: 0.9015
# Epoch 70/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7451 - loss: 0.8841
# Epoch 71/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7670 - loss: 0.8313
# Epoch 72/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7597 - loss: 0.8679
# Epoch 73/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7697 - loss: 0.8290
# Epoch 74/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7608 - loss: 0.8515
# Epoch 75/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7558 - loss: 0.8244
# Epoch 76/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7605 - loss: 0.8489
# Epoch 77/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7576 - loss: 0.8468
# Epoch 78/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7568 - loss: 0.8261
# Epoch 79/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7724 - loss: 0.8410
# Epoch 80/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7757 - loss: 0.7881
# Epoch 81/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7818 - loss: 0.7598
# Epoch 82/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7961 - loss: 0.7364
# Epoch 83/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7831 - loss: 0.7449
# Epoch 84/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8046 - loss: 0.7270
# Epoch 85/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8034 - loss: 0.7371
# Epoch 86/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8054 - loss: 0.7358
# Epoch 87/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8108 - loss: 0.7143
# Epoch 88/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7958 - loss: 0.7122
# Epoch 89/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8198 - loss: 0.6975
# Epoch 90/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8015 - loss: 0.7070
# Epoch 91/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7821 - loss: 0.7480
# Epoch 92/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8036 - loss: 0.6961
# Epoch 93/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8196 - loss: 0.6619
# Epoch 94/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8413 - loss: 0.6365
# Epoch 95/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8052 - loss: 0.7258
# Epoch 96/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8113 - loss: 0.6499
# Epoch 97/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8301 - loss: 0.6434
# Epoch 98/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8393 - loss: 0.6327
# Epoch 99/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8322 - loss: 0.6428
# Epoch 100/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8512 - loss: 0.6176
# Learning is ar drte thtiocala uss cata tatputpelacr anel of t
